# %% [markdown]
# <a href="https://colab.research.google.com/github/joooser/COMPRA-VENTA/blob/cedula-OCR/Copy_of_Final_Finetune_donut_(for_your_own_dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q transformers datasets sentencepiece
# !pip install -q pytorch-lightning wandb
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 3.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 1.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 401.2/401.2 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.2/802.2 kB 11.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 22.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.5/841.5 kB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 28.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.8/266.8 kB 27.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.3 MB/s eta 0:00:00

# %%
from google.colab import drive
import os
from datasets import load_dataset
drive.mount('/content/drive')
# can now access folder with: os.listdir("gdrive/MyDrive/preparedFinetuneData/test")
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers==4.25.1
# Out:
# Collecting transformers==4.25.1
#   Downloading transformers-4.25.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (0.23.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (2.31.0)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.25.1)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 40.4 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers==4.25.1) (4.66.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.10.0->transformers==4.25.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.25.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.25.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.25.1) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers==4.25.1) (2024.2.2)
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.19.1
#     Uninstalling tokenizers-0.19.1:
#       Successfully uninstalled tokenizers-0.19.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.40.1
#     Uninstalling transformers-4.40.1:
#       Successfully uninstalled transformers-4.40.1
# Successfully installed tokenizers-0.13.3 transformers-4.25.1

# %%
# !pip install sconf
# !pip install donut-python
# !pip install pytorch-lightning #MAKE SURE VERSION IS 2.0.7
# !pip install timm==0.5.4
#!pip install transformers
#!pip install pytorch-lightning==1.6.4
#!pip install transformers==4.11.3
# Out:
# Collecting sconf
#   Downloading sconf-0.2.5-py3-none-any.whl (8.8 kB)
# Collecting ruamel.yaml (from sconf)
#   Downloading ruamel.yaml-0.18.6-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 780.6 kB/s eta 0:00:00
# Collecting munch (from sconf)
#   Downloading munch-4.0.0-py2.py3-none-any.whl (9.9 kB)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml->sconf)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: ruamel.yaml.clib, munch, ruamel.yaml, sconf
# Successfully installed munch-4.0.0 ruamel.yaml-0.18.6 ruamel.yaml.clib-0.2.8 sconf-0.2.5
# Collecting donut-python
#   Downloading donut_python-1.0.9-py3-none-any.whl (21 kB)
# Requirement already satisfied: transformers>=4.11.3 in /usr/local/lib/python3.10/dist-packages (from donut-python) (4.25.1)
# Collecting timm (from donut-python)
#   Downloading timm-0.9.16-py3-none-any.whl (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: datasets[vision] in /usr/local/lib/python3.10/dist-packages (from donut-python) (2.19.0)
# Requirement already satisfied: pytorch-lightning>=1.6.4 in /usr/local/lib/python3.10/dist-packages (from donut-python) (2.2.4)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from donut-python) (3.8.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from donut-python) (0.1.99)
# Collecting zss (from donut-python)
#   Downloading zss-1.2.0.tar.gz (9.8 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: sconf>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from donut-python) (0.2.5)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (1.25.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=1.6.4->donut-python) (0.11.2)
# Requirement already satisfied: ruamel.yaml in /usr/local/lib/python3.10/dist-packages (from sconf>=0.2.3->donut-python) (0.18.6)
# Requirement already satisfied: munch in /usr/local/lib/python3.10/dist-packages (from sconf>=0.2.3->donut-python) (4.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->donut-python) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->donut-python) (0.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->donut-python) (2023.12.25)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->donut-python) (2.31.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.11.3->donut-python) (0.13.3)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (2.0.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (3.9.5)
# Requirement already satisfied: Pillow>=6.2.1 in /usr/local/lib/python3.10/dist-packages (from datasets[vision]->donut-python) (9.4.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->donut-python) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->donut-python) (1.4.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm->donut-python) (0.17.1+cu121)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->donut-python) (0.4.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from zss->donut-python) (1.16.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->donut-python) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->donut-python) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->donut-python) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->donut-python) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->donut-python) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets[vision]->donut-python) (4.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning>=1.6.4->donut-python) (67.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.11.3->donut-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.11.3->donut-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.11.3->donut-python) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.11.3->donut-python) (2024.2.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (12.4.127)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets[vision]->donut-python) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets[vision]->donut-python) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets[vision]->donut-python) (2024.1)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /usr/local/lib/python3.10/dist-packages (from ruamel.yaml->sconf>=0.2.3->donut-python) (0.2.8)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch-lightning>=1.6.4->donut-python) (1.3.0)
# Building wheels for collected packages: zss
#   Building wheel for zss (setup.py) ... done
#   Created wheel for zss: filename=zss-1.2.0-py3-none-any.whl size=6724 sha256=ae5857af245fa85ce750f778cd86905371eb9057623ef977afd0bfffdb5317d6
#   Stored in directory: /root/.cache/pip/wheels/f6/61/2a/cf33ab7301cc318a13418d9a805c1832be561b46e7d9337625
# Successfully built zss
# Installing collected packages: zss, timm, donut-python
# Successfully installed donut-python-1.0.9 timm-0.9.16 zss-1.2.0
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (2.2.4)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (1.25.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2.2.1+cu121)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.66.2)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (6.0.1)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (2023.6.0)
# Requirement already satisfied: torchmetrics>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (1.3.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (24.0)
# Requirement already satisfied: typing-extensions>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (4.11.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning) (0.11.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (2.31.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities>=0.8.0->pytorch-lightning) (67.7.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (3.14.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (3.1.3)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->pytorch-lightning) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.13.0->pytorch-lightning) (12.4.127)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->pytorch-lightning) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->fsspec[http]>=2022.5.0->pytorch-lightning) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13.0->pytorch-lightning) (1.3.0)
# Collecting timm==0.5.4
#   Downloading timm-0.5.4-py3-none-any.whl (431 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.5/431.5 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4) (2.2.1+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==0.5.4) (0.17.1+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (2023.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4->timm==0.5.4) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.4->timm==0.5.4) (12.4.127)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.5.4) (1.25.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==0.5.4) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4->timm==0.5.4) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4->timm==0.5.4) (1.3.0)
# Installing collected packages: timm
#   Attempting uninstall: timm
#     Found existing installation: timm 0.9.16
#     Uninstalling timm-0.9.16:
#       Successfully uninstalled timm-0.9.16
# Successfully installed timm-0.5.4

# %%
# @title
#required functions to train
"""
Donut
Copyright (c) 2022-present NAVER Corp.
MIT License
"""
import math
import random
import re
from pathlib import Path

import numpy as np
import pytorch_lightning as pl
import torch
from nltk import edit_distance
from pytorch_lightning.utilities import rank_zero_only
from timm.data.constants import IMAGENET_DEFAULT_MEAN, IMAGENET_DEFAULT_STD
from torch.nn.utils.rnn import pad_sequence
from torch.optim.lr_scheduler import LambdaLR
from torch.utils.data import DataLoader

from donut import DonutConfig, DonutModel


class DonutModelPLModule(pl.LightningModule):
    def __init__(self, config):
        super().__init__()
        self.config = config

        if self.config.get("pretrained_model_name_or_path", False):
            self.model = DonutModel.from_pretrained(
                self.config.pretrained_model_name_or_path,
                input_size=self.config.input_size,
                max_length=self.config.max_length,
                align_long_axis=self.config.align_long_axis,
                ignore_mismatched_sizes=True,
            )
        else:
            self.model = DonutModel(
                config=DonutConfig(
                    input_size=self.config.input_size,
                    max_length=self.config.max_length,
                    align_long_axis=self.config.align_long_axis,
                    # with DonutConfig, the architecture customization is available, e.g.,
                    # encoder_layer=[2,2,14,2], decoder_layer=4, ...
                )
            )
        self.pytorch_lightning_version_is_1 = int(pl.__version__[0]) < 2
        self.num_of_loaders = len(self.config.dataset_name_or_paths)

    def training_step(self, batch, batch_idx):
        image_tensors, decoder_input_ids, decoder_labels = list(), list(), list()
        for batch_data in batch:
            image_tensors.append(batch_data[0])
            decoder_input_ids.append(batch_data[1][:, :-1])
            decoder_labels.append(batch_data[2][:, 1:])
        image_tensors = torch.cat(image_tensors)
        decoder_input_ids = torch.cat(decoder_input_ids)
        decoder_labels = torch.cat(decoder_labels)
        loss = self.model(image_tensors, decoder_input_ids, decoder_labels)[0]
        self.log_dict({"train_loss": loss}, sync_dist=True)
        if not self.pytorch_lightning_version_is_1:
            self.log('loss', loss, prog_bar=True)
        return loss

    def on_validation_epoch_start(self) -> None:
        super().on_validation_epoch_start()
        self.validation_step_outputs = [[] for _ in range(self.num_of_loaders)]
        return

    def validation_step(self, batch, batch_idx, dataloader_idx=0):
        image_tensors, decoder_input_ids, prompt_end_idxs, answers = batch
        decoder_prompts = pad_sequence(
            [input_id[: end_idx + 1] for input_id, end_idx in zip(decoder_input_ids, prompt_end_idxs)],
            batch_first=True,
        )

        preds = self.model.inference(
            image_tensors=image_tensors,
            prompt_tensors=decoder_prompts,
            return_json=False,
            return_attentions=False,
        )["predictions"]

        scores = list()
        for pred, answer in zip(preds, answers):
            pred = re.sub(r"(?:(?<=>) | (?=</s_))", "", pred)
            answer = re.sub(r"<.*?>", "", answer, count=1)
            answer = answer.replace(self.model.decoder.tokenizer.eos_token, "")
            scores.append(edit_distance(pred, answer) / max(len(pred), len(answer)))

            if self.config.get("verbose", False) and len(scores) == 1:
                self.print(f"Prediction: {pred}")
                self.print(f"    Answer: {answer}")
                self.print(f" Normed ED: {scores[0]}")

        self.validation_step_outputs[dataloader_idx].append(scores)

        return scores

    def on_validation_epoch_end(self):
        assert len(self.validation_step_outputs) == self.num_of_loaders
        cnt = [0] * self.num_of_loaders
        total_metric = [0] * self.num_of_loaders
        val_metric = [0] * self.num_of_loaders
        for i, results in enumerate(self.validation_step_outputs):
            for scores in results:
                cnt[i] += len(scores)
                total_metric[i] += np.sum(scores)
            val_metric[i] = total_metric[i] / cnt[i]
            val_metric_name = f"val_metric_{i}th_dataset"
            self.log_dict({val_metric_name: val_metric[i]}, sync_dist=True)
        self.log_dict({"val_metric": np.sum(total_metric) / np.sum(cnt)}, sync_dist=True)

    def configure_optimizers(self):

        max_iter = None

        if int(self.config.get("max_epochs", -1)) > 0:
            assert len(self.config.train_batch_sizes) == 1, "Set max_epochs only if the number of datasets is 1"
            max_iter = (self.config.max_epochs * self.config.num_training_samples_per_epoch) / (
                self.config.train_batch_sizes[0] * torch.cuda.device_count() * self.config.get("num_nodes", 1)
            )

        if int(self.config.get("max_steps", -1)) > 0:
            max_iter = min(self.config.max_steps, max_iter) if max_iter is not None else self.config.max_steps

        assert max_iter is not None
        optimizer = torch.optim.Adam(self.parameters(), lr=self.config.lr)
        scheduler = {
            "scheduler": self.cosine_scheduler(optimizer, max_iter, self.config.warmup_steps),
            "name": "learning_rate",
            "interval": "step",
        }
        return [optimizer], [scheduler]

    @staticmethod
    def cosine_scheduler(optimizer, training_steps, warmup_steps):
        def lr_lambda(current_step):
            if current_step < warmup_steps:
                return current_step / max(1, warmup_steps)
            progress = current_step - warmup_steps
            progress /= max(1, training_steps - warmup_steps)
            return max(0.0, 0.5 * (1.0 + math.cos(math.pi * progress)))

        return LambdaLR(optimizer, lr_lambda)

    @rank_zero_only
    def on_save_checkpoint(self, checkpoint):
        save_path = Path(self.config.result_path) / self.config.exp_name / self.config.exp_version
        self.model.save_pretrained(save_path)
        self.model.decoder.tokenizer.save_pretrained(save_path)


class DonutDataPLModule(pl.LightningDataModule):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.train_batch_sizes = self.config.train_batch_sizes
        self.val_batch_sizes = self.config.val_batch_sizes
        self.train_datasets = []
        self.val_datasets = []
        self.g = torch.Generator()
        self.g.manual_seed(self.config.seed)

    def train_dataloader(self):
        loaders = list()
        for train_dataset, batch_size in zip(self.train_datasets, self.train_batch_sizes):
            loaders.append(
                DataLoader(
                    train_dataset,
                    batch_size=batch_size,
                    num_workers=self.config.num_workers,
                    pin_memory=True,
                    worker_init_fn=self.seed_worker,
                    generator=self.g,
                    shuffle=True,
                )
            )
        return loaders

    def val_dataloader(self):
        loaders = list()
        for val_dataset, batch_size in zip(self.val_datasets, self.val_batch_sizes):
            loaders.append(
                DataLoader(
                    val_dataset,
                    batch_size=batch_size,
                    pin_memory=True,
                    shuffle=False,
                )
            )
        return loaders

    @staticmethod
    def seed_worker(wordker_id):
        worker_seed = torch.initial_seed() % 2 ** 32
        np.random.seed(worker_seed)
        random.seed(worker_seed)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
CONFIG_NAME = "train_cord_finetune.yaml"
CONFIG_PATH = f"/content/drive/MyDrive/preparedFinetuneData/train_cord_finetune.yaml" #file uploaded to google drive

# %%
#train.py file from Donut
"""
Donut
Copyright (c) 2022-present NAVER Corp.
MIT License
"""
import argparse
import datetime
import json
import os
import random
from io import BytesIO
from os.path import basename
from pathlib import Path
import torch.nn as nn
import numpy as np
import pytorch_lightning as pl
import torch
from pytorch_lightning.callbacks import LearningRateMonitor, ModelCheckpoint
from pytorch_lightning.loggers.tensorboard import TensorBoardLogger
from pytorch_lightning.plugins import CheckpointIO
from pytorch_lightning.utilities import rank_zero_only
from sconf import Config

from donut import DonutDataset
#from lightning_module import DonutDataPLModule, DonutModelPLModule #these are now declared above


class CustomCheckpointIO(CheckpointIO):
    def save_checkpoint(self, checkpoint, path, storage_options=None):
        if (checkpoint.get("state_dict", None) is not None):
          del checkpoint["state_dict"]
        torch.save(checkpoint, path)

    def load_checkpoint(self, path, storage_options=None):
        checkpoint = torch.load(path + "artifacts.ckpt")
        state_dict = torch.load(path + "pytorch_model.bin")
        checkpoint["state_dict"] = {"model." + key: value for key, value in state_dict.items()}
        return checkpoint

    def remove_checkpoint(self, path) -> None:
        return super().remove_checkpoint(path)


@rank_zero_only
def save_config_file(config, path):
    if not Path(path).exists():
        os.makedirs(path)
    save_path = Path(path) / "config.yaml"
    print(config.dumps())
    with open(save_path, "w") as f:
        f.write(config.dumps(modified_color=None, quote_str=True))
        print(f"Config is saved at {save_path}")


class ProgressBar(pl.callbacks.TQDMProgressBar):
    def __init__(self, config):
        super().__init__()
        self.enable = True
        self.config = config

    def disable(self):
        self.enable = False

    def get_metrics(self, trainer, model):
        items = super().get_metrics(trainer, model)
        items.pop("v_num", None)
        items["exp_name"] = f"{self.config.get('exp_name', '')}"
        items["exp_version"] = f"{self.config.get('exp_version', '')}"
        return items


def set_seed(seed):
    pytorch_lightning_version = int(pl.__version__[0])
    if pytorch_lightning_version < 2:
        pl.utilities.seed.seed_everything(seed, workers=True)
    else:
        import lightning_fabric
        lightning_fabric.utilities.seed.seed_everything(seed, workers=True)


def train(config):
    set_seed(config.get("seed", 42))

    model_module = DonutModelPLModule(config)
    data_module = DonutDataPLModule(config)

    # add datasets to data_module
    datasets = {"train": [], "validation": []}
    for i, dataset_name_or_path in enumerate(config.dataset_name_or_paths):
        task_name = os.path.basename(dataset_name_or_path)  # e.g., cord-v2, docvqa, rvlcdip, ...

        # add categorical special tokens (optional)
        if task_name == "rvlcdip":
            model_module.model.decoder.add_special_tokens([
                "<advertisement/>", "<budget/>", "<email/>", "<file_folder/>",
                "<form/>", "<handwritten/>", "<invoice/>", "<letter/>",
                "<memo/>", "<news_article/>", "<presentation/>", "<questionnaire/>",
                "<resume/>", "<scientific_publication/>", "<scientific_report/>", "<specification/>"
            ])
        if task_name == "docvqa":
            model_module.model.decoder.add_special_tokens(["<yes/>", "<no/>"])

        for split in ["train", "validation"]:
            datasets[split].append(
                DonutDataset(
                    dataset_name_or_path= f"/content/drive/MyDrive/preparedFinetuneData",
                    donut_model=model_module.model,
                    max_length=config.max_length,
                    split=split,
                    task_start_token=config.task_start_tokens[i]
                    if config.get("task_start_tokens", None)
                    else f"<s_{task_name}>",
                    prompt_end_token="<s_answer>" if "docvqa" in dataset_name_or_path else f"<s_{task_name}>",
                    sort_json_key=config.sort_json_key,
                )
            )
            # prompt_end_token is used for ignoring a given prompt in a loss function
            # for docvqa task, i.e., {"question": {used as a prompt}, "answer": {prediction target}},
            # set prompt_end_token to "<s_answer>"

    data_module.train_datasets = datasets["train"]
    data_module.val_datasets = datasets["validation"]

    logger = TensorBoardLogger(
        save_dir=config.result_path,
        name=config.exp_name,
        version=config.exp_version,
        default_hp_metric=False,
    )

    lr_callback = LearningRateMonitor(logging_interval="step")

    checkpoint_callback = ModelCheckpoint(
        monitor="val_metric",
        dirpath=Path(config.result_path) / config.exp_name / config.exp_version,
        filename="artifacts",
        save_top_k=1,
        save_last=False,
        mode="min",
    )

    bar = ProgressBar(config)

    custom_ckpt = CustomCheckpointIO()
    trainer = pl.Trainer(
        num_nodes=config.get("num_nodes", 1),
        devices=torch.cuda.device_count(),
        #strategy="ddp", #NOTE must comment out strategy, if not you get error
        accelerator="gpu",
        plugins=custom_ckpt,
        max_epochs=config.max_epochs,
        max_steps=config.max_steps,
        val_check_interval=config.val_check_interval,
        check_val_every_n_epoch=config.check_val_every_n_epoch,
        gradient_clip_val=config.gradient_clip_val,


        precision=16,
        num_sanity_val_steps=0,
        logger=logger,
        callbacks=[lr_callback, checkpoint_callback, bar],
    )

    trainer.fit(model_module, data_module, ckpt_path=config.get("resume_from_checkpoint_path", None))
    trainer.save_checkpoint(f"{Path(config.result_path)}/{config.exp_name}/{config.exp_version}/model_checkpoint.ckpt")


if __name__ == "__main__":

    config = Config(CONFIG_PATH)
    config.argv_update([])

    config.exp_name = basename(CONFIG_NAME).split(".")[0]
    config.exp_version = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")

    config.dataset_name_or_paths = ["drive/MyDrive/preparedFinetuneData"]
    config.train_batch_sizes = [1]
    config.check_val_every_n_epoch = 1
    config.max_steps = 500 # infinite, since max_epochs is specified
    config.num_workers = 1 #recommended max
    config.num_nodes = 1
    config.pretrained_model_name_or_path= "naver-clova-ix/donut-base-finetuned-cord-v2" #donut finetuned on Cord dataset
    config.warmup_steps = 0
    print("config path:" , Path(config.result_path),config.exp_name, config.exp_version)
    save_config_file(config, Path(config.result_path) / config.exp_name / config.exp_version)
    train(config)
# Out:
# config path: drive/MyDrive/results train_cord_finetune 20240505_182451
# resume_from_checkpoint_path: None
# result_path: ./drive/MyDrive/results
# pretrained_model_name_or_path: naver-clova-ix/donut-base-finetuned-cord-v2
# dataset_name_or_paths:
#   - drive/MyDrive/preparedFinetuneData
# sort_json_key: True
# train_batch_sizes:
#   - 1
# val_batch_sizes:
#   - 1
# input_size:
#   - 1280
#   - 960
# max_length: 768
# align_long_axis: False
# num_nodes: 1
# seed: 2022
# lr: 3e-05
# warmup_steps: 0
# num_training_samples_per_epoch: 800
# max_epochs: 3
# max_steps: 500
# num_workers: 1
# val_check_interval: 1.0
# check_val_every_n_epoch: 1
# gradient_clip_val: 1.0
# verbose: True
# exp_name: train_cord_finetune
# exp_version: 20240505_182451
# Config is saved at drive/MyDrive/results/train_cord_finetune/20240505_182451/config.yaml
# INFO:lightning_fabric.utilities.seed:Seed set to 2022
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/404 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/859M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:507: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3549.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# sentencepiece.bpe.model:   0%|          | 0.00/1.30M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/335 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/536 [00:00<?, ?B/s]
# Resolving data files:   0%|          | 0/115 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/68 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/41 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/117 [00:00<?, ?files/s]
# Downloading data:   0%|          | 0/70 [00:00<?, ?files/s]
# Downloading data:   0%|          | 0/43 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Generating validation split: 0 examples [00:00, ? examples/s]
# Generating test split: 0 examples [00:00, ? examples/s]
# Resolving data files:   0%|          | 0/115 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/68 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/41 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/lightning_fabric/connector.py:563: `precision=16` is supported for historical reasons but its usage is discouraged. Please set your precision to 16-mixed instead!
# INFO:pytorch_lightning.utilities.rank_zero:Using 16bit Automatic Mixed Precision (AMP)
# INFO:pytorch_lightning.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO:pytorch_lightning.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO:pytorch_lightning.utilities.rank_zero:IPU available: False, using: 0 IPUs
# INFO:pytorch_lightning.utilities.rank_zero:HPU available: False, using: 0 HPUs
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# /usr/local/lib/python3.10/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:653: Checkpoint directory /content/drive/MyDrive/results/train_cord_finetune/20240505_182451 exists and is not empty.
# INFO:pytorch_lightning.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:pytorch_lightning.callbacks.model_summary:
#   | Name  | Type       | Params
# -------------------------------------
# 0 | model | DonutModel | 201 M
# -------------------------------------
# 201 M     Trainable params
# 0         Non-trainable params
# 201 M     Total params
# 804.565   Total estimated model params size (MB)
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Training: |          | 0/? [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# Validation: |          | 0/? [00:00<?, ?it/s]
# Prediction: <s_nombres>HENRY ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-19</s_f_vencimiento><s_f_nacimiento>15/4/1969</s_f_nacimiento><s_f_expedicion>25/3/2009</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 9.913.692</s_cedula><s_apellidos>ROSA CARRASQUEL</s_apellidos>
#     Answer: <s_nombres>HENRY ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-19</s_f_vencimiento><s_f_nacimiento>15/4/1969</s_f_nacimiento><s_f_expedicion>25/3/2009</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 9.913.692</s_cedula><s_apellidos>ROSA CARRASQUEL</s_apellidos>
#  Normed ED: 0.00964630225080386
# Prediction: <s_nombres>JOSE ALFREDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>17/12/1982</s_f_nacimiento><s_f_expedicion>8/8/2012</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 15.913.122</s_cedula><s_apellidos>TORRES BLANCO</s_apellidos>
#     Answer: <s_nombres>JOSE ALFREDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-22</s_f_vencimiento><s_f_nacimiento>17/12/1982</s_f_nacimiento><s_f_expedicion>8/8/2012</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 15.913.122</s_cedula><s_apellidos>TORRES BLANCO</s_apellidos>
#  Normed ED: 0.00967741935483871
# Prediction: <s_nombres>JOSE MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>20/11/1985</s_f_nacimiento><s_f_expedicion>6/1/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.743.716</s_cedula><s_apellidos>RIVAS MARQUEZ</s_apellidos>
#     Answer: <s_nombres>JOSE MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-20</s_f_vencimiento><s_f_nacimiento>20/11/1985</s_f_nacimiento><s_f_expedicion>6/1/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.743.716</s_cedula><s_apellidos>RIVAS MARQUEZ</s_apellidos>
#  Normed ED: 0.009708737864077669
# Prediction: <s_nombres>CARLOS ERNESTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>30/11/1978</s_f_nacimiento><s_f_expedicion>19/7/2011</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.6785.026</s_cedula><s_apellidos>IZQUIERDO CASTILLO</s_apellidos>
#     Answer: <s_nombres>CARLOS ERNESTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-22</s_f_vencimiento><s_f_nacimiento>30/11/1978</s_f_nacimiento><s_f_expedicion>19/7/2011</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.6785.026</s_cedula><s_apellidos>IZQUIERDO CASTILLO</s_apellidos>
#  Normed ED: 0.009404388714733543
# Prediction: <s_nombres>VICTOR</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>4/5/1947</s_f_nacimiento><s_f_expedicion>26/3/2012</s_f_expedicion><s_edo_civil>DIVORC.</s_edo_civil><s_cedula>V 3.432.306</s_cedula><s_apellidos>PETRASEVICIUS MELYNAITE</s_apellidos>
#     Answer: <s_nombres>VICTOR</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-22</s_f_vencimiento><s_f_nacimiento>4/5/1947</s_f_nacimiento><s_f_expedicion>26/3/2012</s_f_expedicion><s_edo_civil>DIVORC.</s_edo_civil><s_cedula>V 3.432.306</s_cedula><s_apellidos>PETRASEVICIUS MELYNAITE</s_apellidos>
#  Normed ED: 0.009615384615384616
# Prediction: <s_nombres>JHONSEN ALBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-19</s_f_vencimiento><s_f_nacimiento>26/4/1977</s_f_nacimiento><s_f_expedicion>6/7/2009</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.950.030</s_cedula><s_apellidos>ALJURE ROJAS</s_apellidos>
#     Answer: <s_nombres>JHONSEN ALBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-19</s_f_vencimiento><s_f_nacimiento>26/4/1977</s_f_nacimiento><s_f_expedicion>6/7/2009</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.950.030</s_cedula><s_apellidos>ALJURE ROJAS</s_apellidos>
#  Normed ED: 0.00964630225080386
# Prediction: <s_nombres>EULOGIO JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-17</s_f_vencimiento><s_f_nacimiento>4/3/1968</s_f_nacimiento><s_f_expedicion>10/9/2007</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.337.457</s_cedula><s_apellidos>HERNANDEZ MALAVE</s_apellidos>
#     Answer: <s_nombres>EULOGIO JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-17</s_f_vencimiento><s_f_nacimiento>4/3/1968</s_f_nacimiento><s_f_expedicion>10/9/2007</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.337.457</s_cedula><s_apellidos>HERNANDEZ MALAVE</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>NANCY COROMOTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>11/9/1966</s_f_nacimiento><s_f_expedicion>6/1/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.989.290</s_cedula><s_apellidos>HERNANDEZ MARQUEZ</s_apellidos>
#     Answer: <s_nombres>NANCY COROMOTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-20</s_f_vencimiento><s_f_nacimiento>11/9/1966</s_f_nacimiento><s_f_expedicion>6/1/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.989.290</s_cedula><s_apellidos>HERNANDEZ MARQUEZ</s_apellidos>
#  Normed ED: 0.009554140127388535
# Prediction: <s_nombres>BRAJHAN JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>30/11/1983</s_f_nacimiento><s_f_expedicion>13/2/2012</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 21.118.091</s_cedula><s_apellidos>TORRES MARQUEZ</s_apellidos>
#     Answer: <s_nombres>BRAJHAN JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>feb-22</s_f_vencimiento><s_f_nacimiento>30/11/1993</s_f_nacimiento><s_f_expedicion>13/2/2012</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 21.118.091</s_cedula><s_apellidos>TORRES MARQUEZ</s_apellidos>
#  Normed ED: 0.009615384615384616
# Prediction: <s_nombres>EMIANUEL RICARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-16</s_f_vencimiento><s_f_nacimiento>30/10/1989</s_f_nacimiento><s_f_expedicion>22/7/2006</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 19.310.594</s_cedula><s_apellidos>MARQUEZ SIERRA</s_apellidos>
#     Answer: <s_nombres>EMMANUEL RICARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-16</s_f_vencimiento><s_f_nacimiento>30/10/1989</s_f_nacimiento><s_f_expedicion>22/7/2006</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 19.310.594</s_cedula><s_apellidos>MARQUEZ SIERRA</s_apellidos>
#  Normed ED: 0.012658227848101266
# Prediction: <s_nombres>ALFREDO JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-17</s_f_vencimiento><s_f_nacimiento>27/8/1976</s_f_nacimiento><s_f_expedicion>9/10/2007</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.414.600</s_cedula><s_apellidos>PERAZA MEZA</s_apellidos>
#     Answer: <s_nombres>ALFREDO JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-17</s_f_vencimiento><s_f_nacimiento>27/8/1976</s_f_nacimiento><s_f_expedicion>9/10/2007</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.414.600</s_cedula><s_apellidos>PERAZA MEZA</s_apellidos>
#  Normed ED: 0.00974025974025974
# Prediction: <s_nombres>ROCCO VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>15/5/1976</s_f_nacimiento><s_f_expedicion>14/1/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.877.265</s_cedula><s_apellidos>D'ORTENZIO TUOZZO</s_apellidos>
#     Answer: <s_nombres>ROCCO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-20</s_f_vencimiento><s_f_nacimiento>15/5/1976</s_f_nacimiento><s_f_expedicion>14/1/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.877.265</s_cedula><s_apellidos>D'ORTENZIO TUOZZO</s_apellidos>
#  Normed ED: 0.10097719869706841
# Prediction: <s_nombres>DONALDO</s_nombres><s_nacionalidad>EXTRANJERO</s_nacionalidad><s_f_vencimiento>oct-cpl-14</s_f_vencimiento><s_f_nacimiento>6/9/1969</s_f_nacimiento><s_f_expedicion>20/6/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>E 83.229.521</s_cedula><s_apellidos>MORA ARDILA</s_apellidos>
#     Answer: <s_nombres>DONALDO</s_nombres><s_nacionalidad>EXTRANJERO</s_nacionalidad><s_f_vencimiento>jun-14</s_f_vencimiento><s_f_nacimiento>6/9/1969</s_f_nacimiento><s_f_expedicion>20/6/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>E 83.229.521</s_cedula><s_apellidos>MORA ARDILA</s_apellidos>
#  Normed ED: 0.02287581699346405
# Prediction: <s_nombres>JOSE VICENCIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-19</s_f_vencimiento><s_f_nacimiento>21/5/1946</s_f_nacimiento><s_f_expedicion>7/7/2009</s_f_expedicion><s_edo_civil>CASADO</s_edo_civil><s_cedula>V 3.242.848</s_cedula><s_apellidos>MENDOZA BLANCO</s_apellidos>
#     Answer: <s_nombres>JOSE VICENCIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-19</s_f_vencimiento><s_f_nacimiento>21/5/1946</s_f_nacimiento><s_f_expedicion>7/7/2009</s_f_expedicion><s_edo_civil>CASADO</s_edo_civil><s_cedula>V 3.242.848</s_cedula><s_apellidos>MEDOZA BLANCO</s_apellidos>
#  Normed ED: 0.012944983818770227
# Prediction: <s_nombres>PETRA LUCIA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-25</s_f_vencimiento><s_f_nacimiento>29/5/1971</s_f_nacimiento><s_f_expedicion>18/9/2015</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.219.389</s_cedula><s_apellidos>GARCIA FERMIN</s_apellidos>
#     Answer: <s_nombres>PETRA LUCIA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-25</s_f_vencimiento><s_f_nacimiento>29/5/1971</s_f_nacimiento><s_f_expedicion>18/9/2015</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.219.389</s_cedula><s_apellidos>GARCIA FERMIN</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>LANDIS DEL CARMEN</s_nombres><s_nacionalidad>VENCRENTO</s_nacionalidad><s_f_vencimiento>sep-14</s_f_vencimiento><s_f_nacimiento>6/5/1980</s_f_nacimiento><s_f_expedicion>29/7/2004</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.449.644</s_cedula><s_apellidos>FERRER URDANETA</s_apellidos>
#     Answer: <s_nombres>LANDIS DEL CARMEN</s_nombres><s_nacionalidad>nan</s_nacionalidad><s_f_vencimiento>jul-14</s_f_vencimiento><s_f_nacimiento>6/5/1980</s_f_nacimiento><s_f_expedicion>29/7/2004</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.449.644</s_cedula><s_apellidos>FERRER URDANETA</s_apellidos>
#  Normed ED: 0.0380952380952381
# Prediction: <s_nombres>MARIA ESTHER</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-17</s_f_vencimiento><s_f_nacimiento>10/12/192</s_f_nacimiento><s_f_expedicion>24/8/2007</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 21.531.068</s_cedula><s_apellidos>GUILLEN PEREZ</s_apellidos>
#     Answer: <s_nombres>MARIA ESTHER</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-17</s_f_vencimiento><s_f_nacimiento>10/12/1992</s_f_nacimiento><s_f_expedicion>24/8/2007</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 21.531.068</s_cedula><s_apellidos>GUILLEN PEREZ</s_apellidos>
#  Normed ED: 0.012861736334405145
# Prediction: <s_nombres>MARIA ANGELICA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>14/12/1982</s_f_nacimiento><s_f_expedicion>7/3/2022</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 23.413.840</s_cedula><s_apellidos>GUERRA LAVEL</s_apellidos>
#     Answer: <s_nombres>MARIA ANGELICA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>14/12/1992</s_f_nacimiento><s_f_expedicion>7/3/2022</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 23.413.840</s_cedula><s_apellidos>GUERRA LAVEL</s_apellidos>
#  Normed ED: 0.01607717041800643
# Prediction: <s_nombres>LUZMNIA ISABEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>6/8/1969</s_f_nacimiento><s_f_expedicion>5/5/2010</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.348.953</s_cedula><s_apellidos>FIGUEROA MONTENEGRO</s_apellidos>
#     Answer: <s_nombres>LUZMANIA ISABEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-20</s_f_vencimiento><s_f_nacimiento>6/8/1969</s_f_nacimiento><s_f_expedicion>5/5/2010</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.348.953</s_cedula><s_apellidos>FIGUEROA MONTENEGRO</s_apellidos>
#  Normed ED: 0.012618296529968454
# Prediction: <s_nombres>MARIA ANGELICA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>14/12/1982</s_f_nacimiento><s_f_expedicion>7/3/2022</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 23.413.840</s_cedula><s_apellidos>GUERRA LAVEL</s_apellidos>
#     Answer: <s_nombres>MARIA ANGELICA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>14/12/1992</s_f_nacimiento><s_f_expedicion>7/3/2022</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 23.413.840</s_cedula><s_apellidos>GUERRA LAVEL</s_apellidos>
#  Normed ED: 0.01607717041800643
# Prediction: <s_nombres>LUIS EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-26</s_f_vencimiento><s_f_nacimiento>26/12/1973</s_f_nacimiento><s_f_expedicion>16/8/2016</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.808.276</s_cedula><s_apellidos>PICON GOMEZ</s_apellidos>
#     Answer: <s_nombres>LUIS EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-26</s_f_vencimiento><s_f_nacimiento>26/12/1973</s_f_nacimiento><s_f_expedicion>16/8/2016</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.808276</s_cedula><s_apellidos>PICON GOMEZ</s_apellidos>
#  Normed ED: 0.012944983818770227
# Prediction: <s_nombres>ANTONIO POMPILIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-14</s_f_vencimiento><s_f_nacimiento>25/2/1947</s_f_nacimiento><s_f_expedicion>18/10/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 3.428.283</s_cedula><s_apellidos>KRIJGER TARIBA</s_apellidos>
#     Answer: <s_nombres>ANTONIO POMPILIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-14</s_f_vencimiento><s_f_nacimiento>25/2/1947</s_f_nacimiento><s_f_expedicion>18/10/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 3.428.283</s_cedula><s_apellidos>KRIJGER TARIBA</s_apellidos>
#  Normed ED: 0.009523809523809525
# Prediction: <s_nombres>LUISETH CAROLINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-18</s_f_vencimiento><s_f_nacimiento>20/9/2000</s_f_nacimiento><s_f_expedicion>26/7/2018</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 27.967.382</s_cedula><s_apellidos>ORTEGA GIMENEZ</s_apellidos>
#     Answer: <s_nombres>LUISETH CAROLINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-18</s_f_vencimiento><s_f_nacimiento>20/9/2000</s_f_nacimiento><s_f_expedicion>26/7/2018</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 27.967.382</s_cedula><s_apellidos>ORTEGA JIMENEZ</s_apellidos>
#  Normed ED: 0.012698412698412698
# Prediction: <s_nombres>PAOLA ANDREINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-27</s_f_vencimiento><s_f_nacimiento>26/7/1993</s_f_nacimiento><s_f_expedicion>8/3/2017</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 24.149.430</s_cedula><s_apellidos>RAMIREZ GOMEZ</s_apellidos>
#     Answer: <s_nombres>PAOLA ANDREINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-27</s_f_vencimiento><s_f_nacimiento>26/7/1993</s_f_nacimiento><s_f_expedicion>8/3/2017</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 24.149.430</s_cedula><s_apellidos>RAMIREZ GOMEZ</s_apellidos>
#  Normed ED: 0.00964630225080386
# Prediction: <s_nombres>BASSIL ALEJANDRO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-21</s_f_vencimiento><s_f_nacimiento>7/5/1950</s_f_nacimiento><s_f_expedicion>13/1/2011</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 20.820.139</s_cedula><s_apellidos>DACOSTA FRIAS</s_apellidos>
#     Answer: <s_nombres>BASSIL ALEJANDRO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-21</s_f_vencimiento><s_f_nacimiento>7/5/1990</s_f_nacimiento><s_f_expedicion>13/1/2011</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 20.820.139</s_cedula><s_apellidos>DACOSTA FRIAS</s_apellidos>
#  Normed ED: 0.003194888178913738
# Prediction: <s_nombres>JAIRO JOHAN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-23</s_f_vencimiento><s_f_nacimiento>2/9/1987</s_f_nacimiento><s_f_expedicion>27/9/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 25.991.172</s_cedula><s_apellidos>ORTIZ BUSTAMANTE</s_apellidos>
#     Answer: <s_nombres>JAIRO JOHAN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-23</s_f_vencimiento><s_f_nacimiento>2/9/1997</s_f_nacimiento><s_f_expedicion>27/9/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 25.991.172</s_cedula><s_apellidos>ORTIZ BUSTAMANTE</s_apellidos>
#  Normed ED: 0.003215434083601286
# Prediction: <s_nombres>DANIEL JEIN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-28</s_f_vencimiento><s_f_nacimiento>5/5/1972</s_f_nacimiento><s_f_expedicion>23/11/2018</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.754.151</s_cedula><s_apellidos>OZAHL ALVAREZ</s_apellidos>
#     Answer: <s_nombres>DANIEL JEIN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-28</s_f_vencimiento><s_f_nacimiento>5/5/1972</s_f_nacimiento><s_f_expedicion>23/11/2018</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.754.151</s_cedula><s_apellidos>OZAHL ALVAREZ</s_apellidos>
#  Normed ED: 0.009708737864077669
# Prediction: <s_nombres>MATTEO</s_nombres><s_nacionalidad>EXTRANJERO</s_nombres><s_nacionalidad>EXTRANJERO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>11/2/1959</s_f_nacimiento><s_f_expedicion>9/1/2008</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>E 84.402.446</s_cedula><s_apellidos>ORNELLI</s_apellidos>
#     Answer: <s_nombres>MATTEO</s_nombres><s_nacionalidad>EXTRANJERO</s_nacionalidad><s_f_vencimiento>dic-08</s_f_vencimiento><s_f_nacimiento>11/2/1959</s_f_nacimiento><s_f_expedicion>9/1/2008</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>E 84.402.446</s_cedula><s_apellidos>ORNELLI</s_apellidos>
#  Normed ED: 0.12835820895522387
# Prediction: <s_nombres>SIMON GERARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-22</s_f_vencimiento><s_f_nacimiento>27/12/1954</s_f_nacimiento><s_f_expedicion>25/10/2012</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 4.632.640</s_cedula><s_apellidos>CENTENO UAREZ</s_apellidos>
#     Answer: <s_nombres>SIMON GERARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-22</s_f_vencimiento><s_f_nacimiento>27/12/1954</s_f_nacimiento><s_f_expedicion>25/10/2012</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 4.632.640</s_cedula><s_apellidos>CENTENO UAREZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>JAIME HUMBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-29</s_f_vencimiento><s_f_nacimiento>14/8/1955</s_f_nacimiento><s_f_expedicion>20/2/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 5.598.238</s_cedula><s_apellidos>LISCANO</s_apellidos>
#     Answer: <s_nombres>JAIME HUMBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>feb-09</s_f_vencimiento><s_f_nacimiento>14/8/1955</s_f_nacimiento><s_f_expedicion>20/2/2019</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 5.598.238</s_cedula><s_apellidos>ROJAS LISCANO</s_apellidos>
#  Normed ED: 0.03215434083601286
# Prediction: <s_nombres>GUSTAVO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-25</s_f_vencimiento><s_f_nacimiento>8/12/1957</s_f_nacimiento><s_f_expedicion>6/12/2015</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 7.244.273</s_cedula><s_apellidos>CARRENO</s_apellidos>
#     Answer: <s_nombres>GUSTAVO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>dic-25</s_f_vencimiento><s_f_nacimiento>8/12/1957</s_f_nacimiento><s_f_expedicion>6/12/2015</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 7.244.273</s_cedula><s_apellidos>CARREÑO</s_apellidos>
#  Normed ED: 0.013422818791946308
# Prediction: <s_nombres>ANGELIQUET MANUELA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-25</s_f_vencimiento><s_f_nacimiento>28/9/1983</s_f_nacimiento><s_f_expedicion>2/12/2015</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 16.307.042</s_cedula><s_apellidos>MARQUEZ SOTO</s_apellidos>
#     Answer: <s_nombres>ANGELIQUET MANUELA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>dic-25</s_f_vencimiento><s_f_nacimiento>28/9/1983</s_f_nacimiento><s_f_expedicion>2/12/2015</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 16.307.042</s_cedula><s_apellidos>MARQUEZ SOTO</s_apellidos>
#  Normed ED: 0.009523809523809525
# Prediction: <s_nombres>AORIANA DEL CARMEN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-14</s_f_vencimiento><s_f_nacimiento>1/3/1980</s_f_nacimiento><s_f_expedicion>26/10/2004</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 14.566.541</s_cedula><s_apellidos>JIMENEZ RAMOS</s_apellidos>
#     Answer: <s_nombres>ARIANA DEL CARMEN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-24</s_f_vencimiento><s_f_nacimiento>1/3/1980</s_f_nacimiento><s_f_expedicion>26/10/2004</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 14.566.541</s_cedula><s_apellidos>JIMENEZ RAMOS</s_apellidos>
#  Normed ED: 0.015822784810126583
# Prediction: <s_nombres>NIEVES JOSEFINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-25</s_f_vencimiento><s_f_nacimiento>31/7/1948</s_f_nacimiento><s_f_expedicion>3/9/2015</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 3.639.648</s_cedula><s_apellidos>ALVAREZ DE GOMEZ</s_apellidos>
#     Answer: <s_nombres>NIEVES JOSEFINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-25</s_f_vencimiento><s_f_nacimiento>31/7/1948</s_f_nacimiento><s_f_expedicion>3/9/2015</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 3.639.648</s_cedula><s_apellidos>ALVAREZ DE GOMEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>JOSE GREGORIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-25</s_f_vencimiento><s_f_nacimiento>12/3/1991</s_f_nacimiento><s_f_expedicion>20/2/2015</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 22.493.089</s_cedula><s_apellidos>CHAVEZ</s_apellidos>
#     Answer: <s_nombres>JOSE GREGORIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>feb-25</s_f_vencimiento><s_f_nacimiento>12/3/1991</s_f_nacimiento><s_f_expedicion>20/2/2015</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 22.493.089</s_cedula><s_apellidos>CHAVEZ</s_apellidos>
#  Normed ED: 0.009868421052631578
# Prediction: <s_nombres>JUAN MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>1/5/1991</s_f_nacimiento><s_f_expedicion>15/4/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 20.467.332</s_cedula><s_apellidos>CHIRINOS</s_apellidos>
#     Answer: <s_nombres>JUAN MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-20</s_f_vencimiento><s_f_nacimiento>1/5/1991</s_f_nacimiento><s_f_expedicion>15/4/2010</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 20.467.332</s_cedula><s_apellidos>CHIRINOS</s_apellidos>
#  Normed ED: 0.009900990099009901
# Prediction: <s_nombres>LANDIS DEL CARMEN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-14</s_f_vencimiento><s_f_nacimiento>6/5/1980</s_f_nacimiento><s_f_expedicion>29/7/2004</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.449.644</s_cedula><s_apellidos>FERRER URDANETA</s_apellidos>
#     Answer: <s_nombres>LANDIS DEL CARMEN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-14</s_f_vencimiento><s_f_nacimiento>6/5/1980</s_f_nacimiento><s_f_expedicion>29/7/2004</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.449.644</s_cedula><s_apellidos>FERRER URDANETA</s_apellidos>
#  Normed ED: 0.00949367088607595
# Prediction: <s_nombres>EDDA MARGARITA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-31</s_f_vencimiento><s_f_nacimiento>16/12/1946</s_f_nacimiento><s_f_expedicion>17/6/2012</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 3.277.537</s_cedula><s_apellidos>MARIN VILLALOBOS</s_apellidos>
#     Answer: <s_nombres>EDDA MARGARITA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jun-31</s_f_vencimiento><s_f_nacimiento>16/12/1946</s_f_nacimiento><s_f_expedicion>17/6/2021</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 3.277.537</s_cedula><s_apellidos>MARIN VILLALOBOS</s_apellidos>
#  Normed ED: 0.015873015873015872
# Prediction: <s_nombres>KRISBEL MARIANNY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-22</s_f_vencimiento><s_f_nacimiento>24/10/1995</s_f_nacimiento><s_f_expedicion>22/8/2012</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 23.764.562</s_cedula><s_apellidos>SALJA RIOS</s_apellidos>
#     Answer: <s_nombres>KRISBEL MARIANNY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-22</s_f_vencimiento><s_f_nacimiento>24/10/1995</s_f_nacimiento><s_f_expedicion>22/8/2012</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 23.764.562</s_cedula><s_apellidos>SALJA RIOS</s_apellidos>
#  Normed ED: 0.009615384615384616
# Prediction: <s_nombres>ARYELIT CAROLINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-16</s_f_vencimiento><s_f_nacimiento>15/1/1977</s_f_nacimiento><s_f_expedicion>8/8/2006</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 12.588.090</s_cedula><s_apellidos>VELARDES ATIENZA</s_apellidos>
#     Answer: <s_nombres>ARYELIT CAROLINA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-16</s_f_vencimiento><s_f_nacimiento>15/1/1977</s_f_nacimiento><s_f_expedicion>8/8/2006</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 12.588.090</s_cedula><s_apellidos>VELARDES ATIENZA</s_apellidos>
#  Normed ED: 0.00949367088607595
# Prediction: <s_nombres>LUAWIG ANTONIO ADE VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-14</s_f_vencimiento><s_f_nacimiento>20/4/1963</s_f_nacimiento><s_f_expedicion>3/6/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 6.123.724</s_cedula><s_apellidos>VERA ROJAS</s_apellidos>
#     Answer: <s_nombres>LUDWIG ANTONIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jun-14</s_f_vencimiento><s_f_nacimiento>20/4/1963</s_f_nacimiento><s_f_expedicion>3/6/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 6.123.724</s_cedula><s_apellidos>VERA ROJAS</s_apellidos>
#  Normed ED: 0.10423452768729642
# Prediction: <s_nombres>LORD MARIO NAPOLEON ISMAEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-14</s_f_vencimiento><s_f_nacimiento>18/2/1985</s_f_nacimiento><s_f_expedicion>20/6/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.668.422</s_cedula><s_apellidos>OPORTO MAESTRE</s_apellidos>
#     Answer: <s_nombres>LORD MARIO NAPOLEON ISMAEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jun-14</s_f_vencimiento><s_f_nacimiento>18/2/1985</s_f_nacimiento><s_f_expedicion>20/6/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.668.422</s_cedula><s_apellidos>OPORTO MAESTRE</s_apellidos>
#  Normed ED: 0.009230769230769232
# Prediction: <s_nombres>JOSE RODOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-25</s_f_vencimiento><s_f_nacimiento>30/12/1962</s_f_nacimiento><s_f_expedicion>21/10/2015</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 6.371.598</s_cedula><s_apellidos>MEDINA CAMPEROS</s_apellidos>
#     Answer: <s_nombres>JOSE RODOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-25</s_f_vencimiento><s_f_nacimiento>30/12/1962</s_f_nacimiento><s_f_expedicion>21/10/2015</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 6.371.598</s_cedula><s_apellidos>MEDINA CAMPEROS</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>CARMEN HAYDEE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-24</s_f_vencimiento><s_f_nacimiento>2/1/1964 DIVORCIADA</s_apellidos>
#     Answer: <s_nombres>CARMEN HAYDEE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-24</s_f_vencimiento><s_f_nacimiento>2/1/1964</s_f_nacimiento><s_f_expedicion>10/11/2014</s_f_expedicion><s_edo_civil>DIVORCIADA</s_edo_civil><s_cedula>V 9.220.059</s_cedula><s_apellidos>BAUTISTA NIETO</s_apellidos>
#  Normed ED: 0.4745222929936306
# Prediction: <s_nombres>MAIDA ZULAY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-16</s_f_vencimiento><s_f_nacimiento>25/7/1951</s_f_nacimiento><s_f_expedicion>3/7/2006</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 3.988.682</s_cedula><s_apellidos>OJEDA DE NORSTROM</s_apellidos>
#     Answer: <s_nombres>MAIDA ZULAY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-16</s_f_vencimiento><s_f_nacimiento>25/7/1951</s_f_nacimiento><s_f_expedicion>3/7/2006</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 3.988.682</s_cedula><s_apellidos>ODEDA DE NORSTROM</s_apellidos>
#  Normed ED: 0.012903225806451613
# Prediction: <s_nombres>DANIEL JEIN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-28</s_f_vencimiento><s_f_nacimiento>5/5/1972</s_f_nacimiento><s_f_expedicion>23/11/2018</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.754.151</s_cedula><s_apellidos>OZAHL ALVAREZ</s_apellidos>
#     Answer: <s_nombres>DANIEL JEIN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-28</s_f_vencimiento><s_f_nacimiento>5/5/1972</s_f_nacimiento><s_f_expedicion>23/11/2018</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.754.151</s_cedula><s_apellidos>OZAHL ALVAREZ</s_apellidos>
#  Normed ED: 0.009708737864077669
# Prediction: <s_nombres>LAURA MARCELA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-17</s_f_vencimiento><s_f_nacimiento>3/9/1978</s_f_nacimiento><s_f_expedicion>3/10/2007</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 13.280.351</s_cedula><s_apellidos>MONSALVE DE GARZON</s_apellidos>
#     Answer: <s_nombres>LAURA MARCELA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-17</s_f_vencimiento><s_f_nacimiento>3/9/1978</s_f_nacimiento><s_f_expedicion>3/10/2007</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 13.280.351</s_cedula><s_apellidos>MONSALVE DE GARZON</s_apellidos>
#  Normed ED: 0.009554140127388535
# Prediction: <s_nombres>LUIS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-16</s_f_vencimiento><s_f_nacimiento>11/1/1941</s_f_nacimiento><s_f_expedicion>29/4/2006</s_f_expedicion><s_edo_civil>CASADO</s_edo_civil><s_cedula>V 2.139.408</s_cedula><s_apellidos>ALCALA COROTHIE</s_apellidos>
#     Answer: <s_nombres>LUIS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-16</s_f_vencimiento><s_f_nacimiento>11/1/1941</s_f_nacimiento><s_f_expedicion>29/4/2006</s_f_expedicion><s_edo_civil>CASADO</s_edo_civil><s_cedula>V 2.139.408</s_cedula><s_apellidos>ALCALA COROTHIE</s_apellidos>
#  Normed ED: 0.00967741935483871
# Prediction: <s_nombres>JOSE NOLBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-23</s_f_vencimiento><s_f_nacimiento>6/6/1957</s_f_nacimiento><s_f_expedicion>28/10/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.170.744</s_cedula><s_apellidos>HERNANDEZ MEJIAS</s_apellidos>
#     Answer: <s_nombres>JOSE NOLBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-23</s_f_vencimiento><s_f_nacimiento>6/6/1957</s_f_nacimiento><s_f_expedicion>28/10/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.170.744</s_cedula><s_apellidos>HRNANDEZ MEJIAS</s_apellidos>
#  Normed ED: 0.003194888178913738
# Prediction: <s_nombres>ZAIMA MARGARITA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-29</s_f_vencimiento><s_f_nacimiento>22/8/1967</s_f_nacimiento><s_f_expedicion>14/11/2019</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.912.215</s_cedula><s_apellidos>TORRES PARRA</s_apellidos>
#     Answer: <s_nombres>ZAIMA MAERGARITA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-29</s_f_vencimiento><s_f_nacimiento>22/8/1967</s_f_nacimiento><s_f_expedicion>14/11/2019</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.912.215</s_cedula><s_apellidos>TORRES PARRA</s_apellidos>
#  Normed ED: 0.012738853503184714
# Prediction: <s_nombres>LORENA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-16</s_f_vencimiento><s_f_nacimiento>30/5/1961</s_f_nacimiento><s_f_expedicion>5/5/2006</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 5.306.447</s_cedula><s_apellidos>COLINA GARCIA</s_apellidos>
#     Answer: <s_nombres>LORENA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-16</s_f_vencimiento><s_f_nacimiento>30/5/1961</s_f_nacimiento><s_f_expedicion>5/5/2006</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 5.306.447</s_cedula><s_apellidos>COLINA GARCIA</s_apellidos>
#  Normed ED: 0.009933774834437087
# Prediction: <s_nombres>LUIS EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-26</s_f_vencimiento><s_f_nacimiento>26/12/1973</s_f_nacimiento><s_f_expedicion>16/8/2016</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.808.276</s_cedula><s_apellidos>PICON GOMEZ</s_apellidos>
#     Answer: <s_nombres>LUIS EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-26</s_f_vencimiento><s_f_nacimiento>26/12/1973</s_f_nacimiento><s_f_expedicion>16/8/2016</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.808.276</s_cedula><s_apellidos>PICON GOMEZ</s_apellidos>
#  Normed ED: 0.009708737864077669
# Prediction: <s_nombres>GABRIEL JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>2/1/1999</s_f_nacimiento><s_f_expedicion>16/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 26.780.854</s_cedula><s_apellidos>SOCORRO SANOJA</s_apellidos>
#     Answer: <s_nombres>GABRIEL JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>2/1/1999</s_f_nacimiento><s_f_expedicion>16/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 26.780.854</s_cedula><s_apellidos>SOCORRO SANOJA</s_apellidos>
#  Normed ED: 0.012903225806451613
# Prediction: <s_nombres>RONNALYS SILVIDISKEILYMAR</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>24/11/1993</s_f_nacimiento><s_f_expedicion>20/9/2010</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.268.514</s_cedula><s_apellidos>LUCENA SUAREZ</s_apellidos>
#     Answer: <s_nombres>RONNALYS SILVIDISKEILYMAR</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>24/11/1993</s_f_nacimiento><s_f_expedicion>20/9/2010</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.268.514</s_cedula><s_apellidos>LUCENA SUAREZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#     Answer: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>MARYURY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-28</s_f_vencimiento><s_f_nacimiento>18/3/1997</s_f_nacimiento><s_f_expedicion>11/1/2018</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 25.594.795</s_cedula><s_apellidos>RIOS PARADA</s_apellidos>
#     Answer: <s_nombres>MARYURY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-28</s_f_vencimiento><s_f_nacimiento>18/3/1997</s_f_nacimiento><s_f_expedicion>11/1/2018</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 25.594.795</s_cedula><s_apellidos>RIOS PARADA</s_apellidos>
#  Normed ED: 0.009900990099009901
# Prediction: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#     Answer: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>ELIGIO JAVIER</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-29</s_f_vencimiento><s_f_nacimiento>3/12/1983</s_f_nacimiento><s_f_expedicion>10/5/2019</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.368.177</s_cedula><s_apellidos>URBINA GOMEZ</s_apellidos>
#     Answer: <s_nombres>ELIGIO JAVIER</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-29</s_f_vencimiento><s_f_nacimiento>3/12/1983</s_f_nacimiento><s_f_expedicion>10/5/2019</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.368.171</s_cedula><s_apellidos>URBINA GOMEZ</s_apellidos>
#  Normed ED: 0.012903225806451613
# Prediction: <s_nombres>JESUS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-22</s_f_vencimiento><s_f_nacimiento>27/11/1984</s_f_nacimiento><s_f_expedicion>23/2/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.887.873</s_cedula><s_apellidos>FEIJOO GARCIA</s_apellidos>
#     Answer: <s_nombres>JESUS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>feb-32</s_f_vencimiento><s_f_nacimiento>27/11/1984</s_f_nacimiento><s_f_expedicion>23/2/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.887.873</s_cedula><s_apellidos>FEIJOO GARCIA</s_apellidos>
#  Normed ED: 0.009615384615384616
# Prediction: <s_nombres>CARLOS ALBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-31</s_f_vencimiento><s_f_nacimiento>18/2/1984</s_f_nacimiento><s_f_expedicion>18/8/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.591.764</s_cedula><s_apellidos>BARAZARTE VEZGA</s_apellidos>
#     Answer: <s_nombres>CARLOS ALBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-31</s_f_vencimiento><s_f_nacimiento>18/2/1984</s_f_nacimiento><s_f_expedicion>18/8/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.591.764</s_cedula><s_apellidos>BARAZARTE VEZGA</s_apellidos>
#  Normed ED: 0.009554140127388535
# Prediction: <s_nombres>KEVIN EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-23</s_f_vencimiento><s_f_nacimiento>29/7/1902</s_f_nacimiento><s_f_expedicion>29/4/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 30.211.759</s_cedula><s_apellidos>LOPEZ SANCHEZ</s_apellidos>
#     Answer: <s_nombres>KEVIN EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-23</s_f_vencimiento><s_f_nacimiento>9/7/2002</s_f_nacimiento><s_f_expedicion>29/4/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 30.211.759</s_cedula><s_apellidos>LOPEZ SANCHEZ</s_apellidos>
#  Normed ED: 0.01929260450160772
# Prediction: <s_nombres>JOSE MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-27</s_f_vencimiento><s_f_nacimiento>20/11/1985</s_f_nacimiento><s_f_expedicion>20/1/2017</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.743.716</s_cedula><s_apellidos>RIVAS MARQUEZ</s_apellidos>
#     Answer: <s_nombres>JOSE MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-27</s_f_vencimiento><s_f_nacimiento>20/11/1985</s_f_nacimiento><s_f_expedicion>20/1/2017</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.743.716</s_cedula><s_apellidos>RIVAS MARQUEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>HEL OR AURELIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-22</s_f_vencimiento><s_f_nacimiento>1/2/1986</s_f_nacimiento><s_f_expedicion>21/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.718.420</s_cedula><s_apellidos>NA PADILLA</s_apellidos>
#     Answer: <s_nombres>HECTOR AURELIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>1/2/1986</s_f_nacimiento><s_f_expedicion>21/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.718.420</s_cedula><s_apellidos>MARENA PADILLA</s_apellidos>
#  Normed ED: 0.03205128205128205
# ...
#     Answer: <s_nombres>CARMEN HAYDEE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-24</s_f_vencimiento><s_f_nacimiento>2/1/1964</s_f_nacimiento><s_f_expedicion>10/11/2014</s_f_expedicion><s_edo_civil>DIVORCIADA</s_edo_civil><s_cedula>V 9.220.059</s_cedula><s_apellidos>BAUTISTA NIETO</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>MAIDA ZULAY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-16</s_f_vencimiento><s_f_nacimiento>25/7/1951</s_f_nacimiento><s_f_expedicion>3/7/2006</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 3.988.682</s_cedula><s_apellidos>ODEDA DE NORSTROM</s_apellidos>
#     Answer: <s_nombres>MAIDA ZULAY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jul-16</s_f_vencimiento><s_f_nacimiento>25/7/1951</s_f_nacimiento><s_f_expedicion>3/7/2006</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 3.988.682</s_cedula><s_apellidos>ODEDA DE NORSTROM</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>DANIEL JEIN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-28</s_f_vencimiento><s_f_nacimiento>5/5/1972</s_f_nacimiento><s_f_expedicion>23/11/2018</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.754.151</s_cedula><s_apellidos>OZAHL ALVAREZ</s_apellidos>
#     Answer: <s_nombres>DANIEL JEIN</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-28</s_f_vencimiento><s_f_nacimiento>5/5/1972</s_f_nacimiento><s_f_expedicion>23/11/2018</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 12.754.151</s_cedula><s_apellidos>OZAHL ALVAREZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>LAURA MARCELA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-17</s_f_vencimiento><s_f_nacimiento>3/9/1978</s_f_nacimiento><s_f_expedicion>3/10/2007</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 13.280.351</s_cedula><s_apellidos>MONSALVE DE GARZON</s_apellidos>
#     Answer: <s_nombres>LAURA MARCELA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-17</s_f_vencimiento><s_f_nacimiento>3/9/1978</s_f_nacimiento><s_f_expedicion>3/10/2007</s_f_expedicion><s_edo_civil>CASADA</s_edo_civil><s_cedula>V 13.280.351</s_cedula><s_apellidos>MONSALVE DE GARZON</s_apellidos>
#  Normed ED: 0.009554140127388535
# Prediction: <s_nombres>LUIS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-16</s_f_vencimiento><s_f_nacimiento>11/1/1941</s_f_nacimiento><s_f_expedicion>29/4/2006</s_f_expedicion><s_edo_civil>CASADO</s_edo_civil><s_cedula>V 2.139.408</s_cedula><s_apellidos>ALCALA COROTHIE</s_apellidos>
#     Answer: <s_nombres>LUIS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-16</s_f_vencimiento><s_f_nacimiento>11/1/1941</s_f_nacimiento><s_f_expedicion>29/4/2006</s_f_expedicion><s_edo_civil>CASADO</s_edo_civil><s_cedula>V 2.139.408</s_cedula><s_apellidos>ALCALA COROTHIE</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>JOSE NOLBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-23</s_f_vencimiento><s_f_nacimiento>6/6/1957</s_f_nacimiento><s_f_expedicion>28/10/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.170.744</s_cedula><s_apellidos>HERNANDEZ MEJIAS</s_apellidos>
#     Answer: <s_nombres>JOSE NOLBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>oct-23</s_f_vencimiento><s_f_nacimiento>6/6/1957</s_f_nacimiento><s_f_expedicion>28/10/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 8.170.744</s_cedula><s_apellidos>HRNANDEZ MEJIAS</s_apellidos>
#  Normed ED: 0.003194888178913738
# Prediction: <s_nombres>ZAIMA MAERGARITA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-29</s_f_vencimiento><s_f_nacimiento>22/8/1967</s_f_nacimiento><s_f_expedicion>14/11/2019</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.912.215</s_cedula><s_apellidos>TORRES PARRA</s_apellidos>
#     Answer: <s_nombres>ZAIMA MAERGARITA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>nov-29</s_f_vencimiento><s_f_nacimiento>22/8/1967</s_f_nacimiento><s_f_expedicion>14/11/2019</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 10.912.215</s_cedula><s_apellidos>TORRES PARRA</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>LORENA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-16</s_f_vencimiento><s_f_nacimiento>30/5/1961</s_f_nacimiento><s_f_expedicion>5/5/2006</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 5.306.447</s_cedula><s_apellidos>COLINA GARCIA</s_apellidos>
#     Answer: <s_nombres>LORENA</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-16</s_f_vencimiento><s_f_nacimiento>30/5/1961</s_f_nacimiento><s_f_expedicion>5/5/2006</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 5.306.447</s_cedula><s_apellidos>COLINA GARCIA</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>LUIS EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-26</s_f_vencimiento><s_f_nacimiento>26/12/1973</s_f_nacimiento><s_f_expedicion>16/8/2016</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.808276</s_cedula><s_apellidos>PICON GOMEZ</s_apellidos>
#     Answer: <s_nombres>LUIS EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-26</s_f_vencimiento><s_f_nacimiento>26/12/1973</s_f_nacimiento><s_f_expedicion>16/8/2016</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 14.808.276</s_cedula><s_apellidos>PICON GOMEZ</s_apellidos>
#  Normed ED: 0.003236245954692557
# Prediction: <s_nombres>GABRIEL JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>2/1/1999</s_f_nacimiento><s_f_expedicion>16/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 26.780.854</s_cedula><s_apellidos>SOCORRO SANOJA</s_apellidos>
#     Answer: <s_nombres>GABRIEL JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>2/1/1999</s_f_nacimiento><s_f_expedicion>16/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 26.780.854</s_cedula><s_apellidos>SOCORRO SANOJA</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>RONNALYS SILVIDISKEILYMAR</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>24/11/1993</s_f_nacimiento><s_f_expedicion>20/9/2010</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.268.514</s_cedula><s_apellidos>LUCENA SUAREZ</s_apellidos>
#     Answer: <s_nombres>RONNALYS SILVIDISKEILYMAR</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>sep-20</s_f_vencimiento><s_f_nacimiento>24/11/1993</s_f_nacimiento><s_f_expedicion>20/9/2010</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 22.268.514</s_cedula><s_apellidos>LUCENA SUAREZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#     Answer: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>MARYURY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-28</s_f_vencimiento><s_f_nacimiento>18/3/1997</s_f_nacimiento><s_f_expedicion>11/1/2018</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 25.594.795</s_cedula><s_apellidos>RIOS PARADA</s_apellidos>
#     Answer: <s_nombres>MARYURY</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-28</s_f_vencimiento><s_f_nacimiento>18/3/1997</s_f_nacimiento><s_f_expedicion>11/1/2018</s_f_expedicion><s_edo_civil>SOLTERA</s_edo_civil><s_cedula>V 25.594.795</s_cedula><s_apellidos>RIOS PARADA</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#     Answer: <s_nombres>GUSTAVO ADOLFO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-14</s_f_vencimiento><s_f_nacimiento>15/12/1970</s_f_nacimiento><s_f_expedicion>4/5/2004</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 10.385.624</s_cedula><s_apellidos>ROJAS HERNANDEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>ELIGIO JAVIER</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-29</s_f_vencimiento><s_f_nacimiento>3/12/1983</s_f_nacimiento><s_f_expedicion>10/5/2019</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.368.1751</s_cedula><s_apellidos>URBINA GOMEZ</s_apellidos>
#     Answer: <s_nombres>ELIGIO JAVIER</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>may-29</s_f_vencimiento><s_f_nacimiento>3/12/1983</s_f_nacimiento><s_f_expedicion>10/5/2019</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.368.171</s_cedula><s_apellidos>URBINA GOMEZ</s_apellidos>
#  Normed ED: 0.003215434083601286
# Prediction: <s_nombres>JESUS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>feb-32</s_f_vencimiento><s_f_nacimiento>27/11/1984</s_f_nacimiento><s_f_expedicion>23/2/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.887.873</s_cedula><s_apellidos>FEIJOO GARCIA</s_apellidos>
#     Answer: <s_nombres>JESUS ENRIQUE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>feb-32</s_f_vencimiento><s_f_nacimiento>27/11/1984</s_f_nacimiento><s_f_expedicion>23/2/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.887.873</s_cedula><s_apellidos>FEIJOO GARCIA</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>CARLOS ALBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-31</s_f_vencimiento><s_f_nacimiento>18/2/1984</s_f_nacimiento><s_f_expedicion>18/8/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.591.764</s_cedula><s_apellidos>BARAZARTE VEZGA</s_apellidos>
#     Answer: <s_nombres>CARLOS ALBERTO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ago-31</s_f_vencimiento><s_f_nacimiento>18/2/1984</s_f_nacimiento><s_f_expedicion>18/8/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 16.591.764</s_cedula><s_apellidos>BARAZARTE VEZGA</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>KEVIN EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-23</s_f_vencimiento><s_f_nacimiento>9/7/2002</s_f_nacimiento><s_f_expedicion>29/4/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 30.211.759</s_cedula><s_apellidos>LOPEZ SANCHEZ</s_apellidos>
#     Answer: <s_nombres>KEVIN EDUARDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-23</s_f_vencimiento><s_f_nacimiento>9/7/2002</s_f_nacimiento><s_f_expedicion>29/4/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 30.211.759</s_cedula><s_apellidos>LOPEZ SANCHEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>JOSE MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-27</s_f_vencimiento><s_f_nacimiento>20/11/1985</s_f_nacimiento><s_f_expedicion>20/1/2017</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.743.716</s_cedula><s_apellidos>RIVAS MARQUEZ</s_apellidos>
#     Answer: <s_nombres>JOSE MANUEL</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-27</s_f_vencimiento><s_f_nacimiento>20/11/1985</s_f_nacimiento><s_f_expedicion>20/1/2017</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.743.716</s_cedula><s_apellidos>RIVAS MARQUEZ</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>hECTOR AURELIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>1/2/1986</s_f_nacimiento><s_f_expedicion>21/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.718.420</s_cedula><s_apellidos>MARENA PADILLA</s_apellidos>
#     Answer: <s_nombres>HECTOR AURELIO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>mar-32</s_f_vencimiento><s_f_nacimiento>1/2/1986</s_f_nacimiento><s_f_expedicion>21/3/2022</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.718.420</s_cedula><s_apellidos>MARENA PADILLA</s_apellidos>
#  Normed ED: 0.003205128205128205
# Prediction: <s_nombres>CARLOS</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jun-31</s_f_vencimiento><s_f_nacimiento>18/9/1986</s_f_nacimiento><s_f_expedicion>11/6/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.534.599</s_cedula><s_apellidos>NIETO ANTILLANO</s_apellidos>
#     Answer: <s_nombres>CARLOS</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>jun-31</s_f_vencimiento><s_f_nacimiento>18/9/1986</s_f_nacimiento><s_f_expedicion>11/6/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.534.599</s_cedula><s_apellidos>NIETO ANTILLANO</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>OLIVER JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-31</s_f_vencimiento><s_f_nacimiento>3/4/1982</s_f_nacimiento><s_f_expedicion>27/4/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 15.759.360</s_cedula><s_apellidos>GONZALEZ AULAR</s_apellidos>
#     Answer: <s_nombres>OLIVER JOSE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>abr-31</s_f_vencimiento><s_f_nacimiento>3/4/1982</s_f_nacimiento><s_f_expedicion>27/4/2021</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 15.759.360</s_cedula><s_apellidos>GONZALEZ AULAR</s_apellidos>
#  Normed ED: 0.0
# Prediction: <s_nombres>DIEGO ARMANDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-23</s_f_vencimiento><s_f_nacimiento>30/11/1986</s_f_nacimiento><s_f_expedicion>16/1/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 18.924.538</s_cedula><s_apellidos>RODRIGUEZ</s_apellidos>
#     Answer: <s_nombres>DIEGO ARMANDO</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-23</s_f_vencimiento><s_f_nacimiento>30/11/1986</s_f_nacimiento><s_f_expedicion>16/1/2013</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 18.924.538</s_cedula><s_apellidos>RODRIGUEZ RODRIGUEZ</s_apellidos>
#  Normed ED: 0.031446540880503145
# Prediction: <s_nombres>RENEE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-30</s_f_vencimiento><s_f_nacimiento>12/5/1987</s_f_nacimiento><s_f_expedicion>20/1/2020</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.533.261</s_cedula><s_apellidos>ZUBELDA CENTENO</s_apellidos>
#     Answer: <s_nombres>RENEE</s_nombres><s_nacionalidad>VENEZOLANO</s_nacionalidad><s_f_vencimiento>ene-30</s_f_vencimiento><s_f_nacimiento>12/5/1987</s_f_nacimiento><s_f_expedicion>20/1/2020</s_f_expedicion><s_edo_civil>SOLTERO</s_edo_civil><s_cedula>V 17.533.261</s_cedula><s_apellidos>ZUBELDA CENTENO</s_apellidos>
#  Normed ED: 0.0
# INFO:pytorch_lightning.utilities.rank_zero:`Trainer.fit` stopped: `max_epochs=3` reached.

# %% [markdown]
# inferencia

# %%
from PIL import Image
# Change the path here:
model = DonutModel.from_pretrained("/content/drive/MyDrive/results/train_cord_finetune/20240505_182451")
if torch.cuda.is_available():
    model.half()
    device = torch.device("cuda")
    model.to(device)
else:
    model.encoder.to(torch.bfloat16)

model.eval()

image = Image.open("/content/drive/MyDrive/CI-PRUEBA/1.jpg") # Change here
with torch.no_grad():
  prompt_tensors = torch.tensor([2])
  output = model.inference(image=image, prompt_tensors=prompt_tensors)

output
# Out:
# {'predictions': [{'text_sequence': '經由 A D L A D E I D E N T I D A D C E N T I D A D A D C E D U L A D E D U L A D E N T I D E N T I D A D A D C E D U L A D L A D E D U L A L A L A L A L A L A L A L A L A L A L A L IZQUIERDO CASTILLO'}]}

# %%
from PIL import Image

# Change the path here:
model = DonutModel.from_pretrained("/content/drive/MyDrive/results/train_cord_finetune/20240505_182451")
if torch.cuda.is_available():
    model.half()
    device = torch.device("cuda")
    model.to(device)
else:
    model.encoder.to(torch.bfloat16)

model.eval()

image = Image.open("/content/drive/MyDrive/CI-PRUEBA/13.jpg") # Change here
with torch.no_grad():
  # Change here to a tensor of size 7
  prompt_tensors = torch.tensor([3])
  output = model.inference(image=image, prompt_tensors=prompt_tensors)

output
# Out:
# {'predictions': [{'nombres': 'CARLOS ERNESTO',
#    'nacionalidad': 'VENEZOLANO',
#    'f_vencimiento': 'jul-22',
#    'f_nacimiento': '30/11/1978',
#    'f_expedicion': '19/7/2011',
#    'edo_civil': 'SOLTERO',
#    'cedula': 'V 14.6785.026',
#    'apellidos': 'IZQUIERDO CASTILLO'}]}
